# %%
import requests
import json
import numpy as np
import pandas as pd
import time

# %%
final_list = []

location_stores = []

for lat in range(3590,3540,-2):
    
    for lon in range(5088,5187,3):
        
#         print('lat : ' , lat/100 , 'lon : ' , lon/100)
                
        location_stores_base_url = 'https://api.snapp.express/mobile/v3/restaurant/vendors-list?lat={}&long={}'.format(lat/100,lon/100)
        
        location_stores_base_dict = {}
        
        j=1
        
        while ((j<3) and (location_stores_base_dict=={})):
            
            try:
                location_stores_base_dict = json.loads((requests.get(location_stores_base_url,timeout=3)).text)
            except:
                j=j+1
        
#         print(location_stores_base_dict)
        
        if(location_stores_base_dict != {}):
            
            try:
                stores_count = location_stores_base_dict['data']['count']
            except:
                stores_count = 0
                
            page = 0       
            
            i = 0          
            
            while(i < stores_count):
                
                location_stores_url = 'https://api.snapp.express/mobile/v3/restaurant/vendors-list?lat={}&long={}&page={}&page_size={}'.format(lat/100, lon/100, page, 20)

                items_list = []
                
                k=1
                
                while ((k<4) and (items_list==[])):
                    
                    try:
                        items_list = (json.loads((requests.get(location_stores_url,timeout=3)).text))['data']['finalResult']
                    except:
                        k=k+1
                        
                if(items_list != []):
                    
                    for item in items_list:

                        if(item['type']=='VENDOR'):

                            i = i+1

                            store_dict = {}

                            try:
                                store_dict['store_id'] = item['data']['id']
                            except:
                                store_dict['store_id'] = '---'
                            try:
                                store_dict['store_code'] = item['data']['vendorCode']
                            except:
                                store_dict['store_code'] = '---'
                            try:
                                store_dict['store_type'] = item['data']['vendorTypeTitle']
                            except:
                                store_dict['store_type'] = '---'
                            try:
                                store_dict['store_name'] = item['data']['title']
                            except:
                                store_dict['store_name'] = '---'
                            try:
                                store_dict['store_rate_five'] = item['data']['rate']
                            except:
                                store_dict['store_rate_five'] = '---'
                            try:
                                store_dict['store_tax'] = item['data']['tax']
                            except:
                                store_dict['store_tax'] = '---'
                            try:
                                store_dict['store_service_fee'] = item['data']['serviceFee']
                            except:
                                store_dict['store_service_fee'] = '---'
                            try:
                                store_dict['store_discount'] = item['data']['discount']
                            except:
                                store_dict['store_discount'] = '---'
                            try:
                                store_dict['store_open'] = item['data']['isOpen']
                            except:
                                store_dict['store_open'] = '---'
                            try:
                                store_dict['store_min_price_order'] = item['data']['minOrder']
                            except:
                                store_dict['store_min_price_order'] = '---'
                            try:
                                store_dict['store_address'] = item['data']['address']
                            except:
                                store_dict['store_address'] = '---'
                            try:
                                store_dict['store_phone'] = item['data']['phone']
                            except:
                                store_dict['store_phone'] = '---'
                            try:
                                store_dict['store_location_lat'] = item['data']['lat']
                            except:
                                store_dict['store_location_lat'] = '---'
                            try:
                                store_dict['store_location_lon'] = item['data']['lon']
                            except:
                                store_dict['store_location_lon'] = '---'
                            try:
                                store_dict['store_priority'] = item['data']['priority']
                            except:
                                store_dict['store_priority'] = '---'
                            try:
                                store_dict['store_city'] = item['data']['city']
                            except:
                                store_dict['store_city'] = '---'
                            try:
                                store_dict['store_area'] = item['data']['area']
                            except:
                                store_dict['store_area'] = '---'
                            try:
                                store_dict['store_comment_count'] = item['data']['commentCount']
                            except:
                                store_dict['store_comment_count'] = '---'
                            try:
                                store_dict['store_vote_count'] = item['data']['voteCount']
                            except:
                                store_dict['store_vote_count'] = '---'
                            try:
                                store_dict['store_container_fee'] = item['data']['containerFee']
                            except:
                                store_dict['store_container_fee'] = '---'
                            try:
                                store_dict['store_discount_for_view'] = item['data']['discountValueForView']
                            except:
                                store_dict['store_discount_for_view'] = '---'
                            try:
                                store_dict['store_budget_class'] = item['data']['budgetClass']
                            except:
                                store_dict['store_budget_class'] = '---'
                            try:
                                store_dict['store_delivery_fee'] = item['data']['deliveryFee']
                            except:
                                store_dict['store_delivery_fee'] = '---'
                            try:
                                store_dict['store_coupon_count'] = item['data']['coupon_count']
                            except:
                                store_dict['store_coupon_count'] = '---'
                            try:
                                store_dict['store_best_coupon'] = item['data']['best_coupon']
                            except:
                                store_dict['store_best_coupon'] = '---'
                            try:
                                store_dict['store_delivery_fee_discount'] = item['data']['deliveryFeeDiscount']
                            except:
                                store_dict['store_delivery_fee_discount'] = '---'

                            location_stores.append(store_dict)
                            
            page = page + 1

# %%
len(location_stores)
# Out:
# 2006

# %%
stores_df = pd.DataFrame(location_stores)

# %%
stores_df.to_excel('stores_df.xlsx')

# %%
stores_df.drop_duplicates().to_excel('stores_df_2.xlsx')

# %%
stores_df.sort_values("store_code", inplace=True)
stores_df.drop_duplicates(subset="store_code",keep='last', inplace=True)
stores_df.to_excel('stores_df_final.xlsx')

# %%
location_stores = stores_df.to_dict('records')

# %%
len(location_stores)
# Out:
# 712

# %%
def extract_type(x):
    
    if('پنیر' in x.split(' ')):
        return 'پنیر'
    elif('شیر' in x.split(' ')):
        return 'شیر'
    elif('ماست' in x.split(' ')):
        return 'ماست'
    elif('دوغ' in x.split(' ')):
        return 'دوغ'
    elif('کره' in x.split(' ')):
        return 'کره'
    elif('خامه' in x.split(' ')):
        return 'خامه'
    elif('کشک' in x.split(' ')):
        return 'کشک'
    elif('بستنی' in x.split(' ')):
        return 'بستنی'
    else:
        return 'سایر'

# %%
dairy_id = 1032

products = []

for store in location_stores:

    store_code = store['store_code']
    
    print(store_code)

    products_base_url = 'https://api.snapp.express/product-list/{}/vendor/{}?page=0&size=10'.format(dairy_id, store_code)

    number_of_products = 0
    
    j = 1
    
    while ((j<7) and (number_of_products == 0)):
        try:
            number_of_products = json.loads(requests.get(products_base_url,timeout=3).text)["data"]["count"]
        except:
            j = j+1

    # print(number_of_products)

    size = 50

    for page in range(0, (number_of_products//size)+1):

        products_url = 'https://api.snapp.express/product-list/{}/vendor/{}?page={}&size={}'.format(dairy_id, store_code, page, size)

        products_list = []

#         print(products_url)
        
        k = 1
    
        while ((k<7) and (products_list == [])):
            try:
                products_list = (json.loads(requests.get(products_url,timeout=3).text))["data"]["finalResult"]
            except:
                k = k+1

        # products_list = (json.loads(requests.get(products_url).text))["data"]["finalResult"]

        for product in products_list:

            product_dict = {}

            try:
                product_dict['product_id'] = product['id']
            except:
                product_dict['product_id'] = '---'
            try:
                product_dict['product_name'] = product['data']['title']
            except:
                product_dict['product_name'] = '---'
            try:
                product_dict['product_discount_rate'] = product['data']['discount_ratio']
            except:
                product_dict['product_discount_rate'] = '---'
            try:
                product_dict['product_discount'] = product['data']['discount']
            except:
                product_dict['product_discount'] = '---'
            try:
                product_dict['product_main_price'] = product['data']['price']
            except:
                product_dict['product_main_price'] = '---'
            try:
                product_dict['product_sale_price'] = (product['data']['price']) - (product['data']['discount'])
            except:
                product_dict['product_sale_price'] = '---'
            try:
                product_dict['product_brand'] = product['data']['brand']
            except:
                product_dict['product_brand'] = '---'
            try:
                product_dict['product_category'] = extract_type(product['data']['title'])
            except:
                product_dict['product_category'] = '---'
            try:
                product_dict['product_stock'] = product['data']['stock']
            except:
                product_dict['product_stock'] = '---'
            try:
                product_dict['product_volume'] = product['data']['description']
            except:
                product_dict['product_volume'] = '---'
            try:
                product_dict['product_rating'] = round(product['data']['rating'], 2)*100
            except:
                product_dict['product_rating'] = '---'
            try:
                product_dict['product_comment_count'] = product['data']['comment_count']
            except:
                product_dict['product_comment_count'] = '---'
            try:
                product_dict['product_store_name'] = store['store_name']
            except:
                product_dict['product_store_name'] = '---'
            try:
                product_dict['product_store_code'] = store['store_code']
            except:
                product_dict['product_store_code'] = '---'

            products.append(product_dict)
# Out:
# 0962dy
# 09746y
# 09748n
# 097646
# 097j76
# 097w8n
# 097xxy
# 097z6q
# 099v5y
# 099y46
# 09e41k
# 09e49q
# 09e4ky
# 09e4ld
# 09ex7q
# 09exed
# 09exen
# 09exvy
# 09exwq
# 09exxy
# 09j1xd
# 09j5d6
# 09j5ky
# 09j5nk
# 09j5wn
# 09jk6n
# 09jk9n
# 09jko6
# 09jkyd
# 09jvkq
# 09wdnk
# 09y64y
# 0g96m2
# 0g98yx
# 0gg4vr
# 0gglor
# 0ggn4x
# 0ggn5n
# 0ggn92
# 0ggz5q
# 0gkl7n
# 0gklg2
# 0gklgx
# 0gklkx
# 0gkll2
# 0gkllr
# 0gklo2
# 0gklqn
# 0gklwr
# 0gkly2
# 0gknlr
# 0gknqn
# 0gknr2
# 0gknwr
# 0gknxq
# 0gkny2
# 0god2n
# 0grn7q
# 0gz54q
# 0gz55r
# 0gz58n
# 0gz5er
# 0gz872
# 0gzdmx
# 0gzonr
# 0gzw9m
# 0gzwjm
# 0gzwjq
# 0gzwkm
# 0gzwmn
# 0gzwyx
# 0j24x6
# 0j27wg
# 0j2nv9
# 0j4e5g
# 0j4e6g
# 0j4ne9
# 0j4yq6
# 0jgd56
# 0jgd86
# 0jgd9v
# 0jgdrg
# 0jgq89
# 0jgv2g
# 0jgv4g
# 0jgvj6
# 0jgvl9
# 0jgvmg
# 0jgvnr
# 0jgvwv
# 0jgvx9
# 0jjedv
# 0jjeov
# 0jjerr
# 0jjyx9
# 0jm4n9
# 0jrmjv
# 0l2yqk
# 0l6xen
# 0l6yxe
# 0l8679
# 0l8er9
# 0l8mdk
# 0ld44k
# 0ldq9k
# 0ldqm9
# 0ldqxe
# 0ldqzj
# 0ldvvk
# 0ldwyz
# 0lek1j
# 0lekxk
# 0lengz
# 0lgxy9
# 0lj21n
# 0lj24j
# 0lj27e
# 0lj2re
# 0lj2vk
# 0lj2ze
# 0ljnnz
# 0lm82j
# 0lme5z
# 0lmn9j
# 0lmx49
# 0m1e9o
# 0m1eor
# 0m1l7r
# 0m1lwq
# 0m1lxr
# 0m1rzo
# 0m1w9o
# 0m1wey
# 0m1wxv
# 0m919o
# 0m9e7r
# 0m9o2q
# 0mje2z
# 0mje5r
# 0mje6q
# 0mje7z
# 0mjezo
# 0mjl1v
# 0mjl7z
# 0mjljr
# 0mjllo
# 0mjlnq
# 0mjlwo
# 0mjlyv
# 0mmxvo
# 0mmz7r
# 0mmzmq
# 0my5ov
# 0my67z
# 0my69r
# 0my6wv
# 0myr2y
# 0myr4r
# 0myr5r
# 0myr7z
# 0myr8y
# 0myrdq
# 0myrgy
# 0myrrq
# 0myrzv
# 0myzmo
# 0ndvor
# 0ngmn6
# 0njl5v
# 0njl62
# 0njlg8
# 0njll8
# 0njlm6
# 0njn4z
# 0njn7z
# 0njnev
# 0njnvr
# 0njny2
# 0nq9dv
# 0nqk16
# 0nqkdz
# 0nqkqz
# 0nqlv8
# 0nqnd8
# 0nqnl2
# 0nqo22
# 0nqvxv
# 0nrge8
# 0nv52r
# 0nv81z
# 0nv862
# 0nv8g8
# 0nv8o2
# 0nv8wr
# 0nv8y6
# 0nv8zv
# 0nvm22
# 0nvm5v
# 0nvmy6
# 0nwerz
# 0nwmzv
# 0nwqj8
# 0nwwl2
# 0q1y2x
# 0q1y4y
# 0q1y7d
# 0q1y9y
# 0q1ygd
# 0q1ynd
# 0q1yqx
# 0q1yz9
# 0q5m4y
# 0q5o9y
# 0q5ojx
# 0q5wr2
# 0q5yzx
# 0qdeyx
# 0qe6y9
# 0qez9d
# 0qljj9
# 0qljkd
# 0qljm9
# 0qljqx
# 0qljxy
# 0qlzm9
# 0qr5g2
# 0rj5qz
# 0ro14v
# 0ro17o
# 0ro1l9
# 0ro1qv
# 0rokk9
# 0rokrz
# 0ror4v
# 0rorl9
# 0rory1
# 0rq57o
# 0rq5l8
# 0rq5m9
# 0rq5z8
# 0rqm7o
# 0rqmjz
# 0rqmk9
# 0rqmo1
# 0rqmr9
# 0rqmvz
# 0rqmz8
# 0rv2xv
# 0rvdvv
# 0rveg1
# 0rx5n1
# 0rxnrv
# 0rxw98
# 0rye1o
# 0ryxj8
# 0ryyd1
# 0ryyro
# 0w1zwq
# 0w428g
# 0w4w7g
# 0w917g
# 0w98lz
# 0w9l1q
# 0wd2rz
# 0wq528
# 0wq5xz
# 0wq5y5
# 0wq5yz
# 0wq5zg
# 0wqd1g
# 0wqd2v
# 0wqdgv
# 0wqdlz
# 0wqdv8
# 0wwl9g
# 0wwldq
# 0wwljv
# 0wwlkv
# 0wwllz
# 0wwlv5
# 0wwq7g
# 0wwqoq
# 0wwxdq
# 0wwxwv
# 0wz5gv
# 0wz61v
# 0wzd2g
# 0wzdmv
# 0y966g
# 0y975y
# 0y976g
# 0y97xn
# 0y9n7d
# 0y9o5y
# 0y9o6g
# 0y9o7g
# 0y9o8r
# 0y9oxm
# 0y9ozy
# 0yg15y
# 0yg1qy
# 0yg1wn
# 0yg1xm
# 0ygy6g
# 0ygyer
# 0yj92d
# 0yjd7m
# 0yjdwr
# 0yjr2d
# 0yjrwd
# 0yryor
# 0yvmzr
# 3146ny
# 314mm2
# 314y2w
# 31j8lw
# 31jjm7
# 31jmkk
# 31l564
# 31m9m4
# 31q624
# 31q662
# 31q697
# 31q6jw
# 31q6ky
# 31q6y7
# 31q764
# 31qom4
# 31qon7
# 31x1n2
# 31x25k
# 31x2ew
# 31x2q4
# 31xrwy
# 31xv22
# 31z262
# 31z287
# 31z2d7
# 31z2gk
# 31z2l4
# 31zv62
# 31zv87
# 31zvjw
# 31zvo2
# 321y82
# 322r45
# 32mew2
# 32q85l
# 32q87q
# 32ql1e
# 32ql7q
# 32qldl
# 32qlj2
# 32qlkd
# 32qlqe
# 32qlvl
# 32qlwl
# 32qlz5
# 32r6o5
# 32r6zq
# 32r7ne
# 32rm6l
# 32rnw2
# 32rogd
# 32x2oe
# 32x9de
# 32xlwd
# 32xmm2
# 32xxwe
# 32xyl2
# 32z6yl
# 32z72q
# 32z7n5
# 32z7qe
# 32z7xq
# 3754x2
# 3756e2
# 375j4g
# 375x4g
# 375x52
# 379ejn
# 37o26m
# 37o2om
# 37o722
# 37o799
# 37o7gg
# 37o7kn
# 37o7nn
# 37o7q2
# 37o7vg
# 37odd2
# 37r4d2
# 37r4gg
# 37r4jx
# 37r4kn
# 37r4yx
# 37rj22
# 37rjgg
# 37ww2n
# 37xw1x
# 37y94n
# 37yqo9
# 3d58mx
# 3d71xn
# 3d7667
# 3d7j47
# 3d7jvd
# 3d7jwx
# 3d7jyg
# 3d7q5w
# 3d7w9d
# 3d7x2x
# 3d7xdx
# 3d7xen
# 3d7xng
# 3d7xrd
# 3d7xzg
# 3del2x
# 3del67
# 3delen
# 3delj7
# 3delkn
# 3deq6g
# 3deqon
# 3dm1ox
# 3dm5qg
# 3dme5x
# 3dmkyw
# 3dml6g
# 3dmled
# 3dq827
# 3dqwzw
# 3dr45w
# 3drnmd
# 3dvr5g
# 3e5zy5
# 3e966v
# 3ee54o
# 3ee58o
# 3ee5km
# 3ee5lm
# 3ee5vj
# 3ee5z2
# 3eele2
# 3eeloo
# 3eq4qj
# 3eq6lv
# 3ew6lm
# 3ez71j
# 3ez7dv
# 3ez7go
# 3ez7l5
# 3ez7nm
# 3ez7w2
# 3ez7xv
# 3ez7yj
# 3ezgv2
# 3ezk22
# 3ezk65
# 3ezk8o
# 3ezkvv
# 3ezkyv
# 3k9m5k
# 3k9m9j
# 3k9mlo
# 3k9mvo
# 3k9yqg
# 3k9yzg
# 3kjl9j
# 3kjleg
# 3kjlgg
# 3kjlvo
# 3kjneg
# 3kjnjj
# 3klmrk
# 3kolzk
# 3kon2j
# 3kv66g
# 3kv92n
# 3kvoek
# 3x1974
# 3x2do9
# 3x2gvw
# 3x2xl6
# 3x2ygy
# 3x5ez4
# 3x5zkw
# 3xgekw
# 3xgenw
# 3xgeq9
# 3xgr6w
# 3xgyjy
# 3xgz22
# 3xgz52
# 3xgz66
# 3xgzdy
# 3xgze4
# 3xgzl9
# 3xgzo6
# 3xgzz4
# 3xrz69
# 3xwd9w
# 3xwdg2
# 3xwdkw
# 3xwdm9
# 3xwdo6
# 3xwdv6
# 3xwdy4
# 3xwynw
# 3xwyw2
# 3xwyx6
# p42lkj
# p47gwy
# p47ler
# p47o9y
# p4g85x
# p4go8j
# p4gxvx
# p4jov5
# p4qd9r
# p4qklj
# p4qndj
# p4qney
# p4qngr
# p4qnyj
# p4qo1y
# p4qo6x
# p4qo95
# p4qoej
# p4qojr
# p4qoox
# p4qoqr
# p4qozj
# p4rn4x
# p4z45y
# p4z48j
# p4z4kj
# p4z4v5
# p4z4yj
# p4zlx5
# p557xv
# p559ge
# p559zw
# p55o6e
# p55q7w
# p5q45v
# p5q47n
# p5q4lx
# p5q4ow
# p5q4wv
# p5q4zn
# p5qgxj
# p5qk2n
# p5qlqe
# p5qx8e
# p5qxke
# p5qxyn
# p5r4oj
# p5r8dj
# p5rj7v
# p5ry8j
# p5w4vn
# p5wxke
# p5z2ex
# p5z2xj
# p5z2zv
# p5zj2j
# p5zo8n
# p5zokn
# p5zomx
# p5zoqv
# p5zovn
# p627vn
# p62o76
# p6746w
# p674gn
# p674wo
# p674xg
# p67d9o
# p6dv16
# p6g2dg
# p6g79o
# p6j6n6
# p6omko
# p6r1ro
# p6re4n
# p6re8o
# p6rege
# p6reno
# p6reqg
# p6rere
# p6rvnw
# p6rx1o
# p6rxe6
# p6rxre
# p6rxx6
# p6rxze
# p6z47w
# p6z4e6
# p6zde6
# p6zdgw
# p6zdjn
# p6zdve
# p8487g
# p84k8g
# p84kz2
# p8751g
# p875l5
# p87612
# p878dm
# p87okg
# p8d51g
# p8djjr
# p8e52g
# p8e56m
# p8e58g
# p8e5lg
# p8e5o5
# p8exmg
# p8exnm
# p8exq2
# p8exxy
# p8exyr
# p8g7v2
# p8gl4m
# p8oj2m
# p8ojlg
# p8ok1m
# p8ok62
# p8okd5
# p8okjr
# p8okkr
# p8oko5
# p8or82
# po6jnj
# po6l1o
# po6l5o
# po6lnv
# po6lrq
# po6lwj
# po6n5o
# po6ndk
# po6nn8
# po6nyq
# po9e8j
# po9qzk
# pog6gk
# pogozk
# pogyqj
# poj91o
# poj9mk
# poj9ov
# poj9vk
# poj9wo
# pojq5o
# pojq7j
# pojql8
# poo5lo
# pooj4v
# pooq2j
# porgzk
# pork88
# poyn1o
# pvj961
# pvj9wd
# pvl641
# pvl67x
# pvl6ld
# pvln1v
# pvln6m
# pvlnrv
# pvlny1
# pvlv9v
# pvq97x
# pvq9d5
# pvq9gm
# pvq9jv
# pvq9n5
# pvqx2x
# pvqx5d
# pvqxwd
# pz86ew
# pz86re
# pz892j
# pz8eg2
# pz8lzo
# pz8n71
# pz8njo
# pz8yoo
# pz962o
# pz96e2
# pz96jw
# pz96w1
# pz9n4w
# pz9n7o
# pz9njw
# pz9nl1
# pz9nw1
# pz9nxo
# pz9nz1
# pzd41j
# pzd42o
# pzd44w
# pzd49e
# pzd4kj
# pzd4vj
# pzd6z1
# pzde6w
# pzdj42
# pzdjmw
# pzek52
# pzk621

# %%
products_df = pd.DataFrame(products)

# %%
products_df.to_excel('products_df.xlsx')

# %%
products_df['product_store_code'].value_counts().index
# Out:
# Index(['37y94n', 'pz962o', '0rxw98', 'p87612', 'p4g85x', 'pvl67x', '0rvdvv',
#        '0qez9d', 'pvlv9v', '0wqdgv',
#        ...
#        '3k9yzg', '0y9o5y', '3kjl9j', '0ldvvk', '0jgvnr', '3delen', 'p5wxke',
#        'po6lwj', '3ezkyv', 'pzdjmw'],
#       dtype='object', length=679)

# %%
products_df[]
# Out:
#         product_id                                       product_name  \
# 0          5244480                          خامه صبحانه پاک (100 گرم)
# 1          4088040                   پنیر خامه ای ویلی کاله (200 گرم)
# 2          4087292                     خامه صبحانه 30٪ کاله (200 گرم)
# 3          4087374              شیر کم چرب 1.5٪ فرادما میهن (یک لیتر)
# 4          5223447                       پنیر لبنه آنا کاله (350 گرم)
# ...            ...                                                ...
# 103069     9710613           پنیر پنج ستاره آمل کلاسیک کاله (350 گرم)
# 103070     9707266  شیر کم چرب غنی شده با ویتامین دی3 می ماس (یک ل...
# 103071     9700340   ماست پرچرب غنی شده با ویتامین دی پاک (2 کیلوگرم)
# 103072     9705792      ماست کم چرب 1.5٪ پروبیوتیک کاله (1.8 کیلوگرم)
# 103073     9710088            ماست کم چرب 1.3٪ مزرعه ماهشام (500 گرم)
#
#         product_rating  product_discount  product_discount_rate  \
# 0                 84.0               0.0                    0.0
# 1                 86.0               0.0                    0.0
# 2                 85.0               0.0                    0.0
# 3                 85.0               0.0                    0.0
# 4                 86.0               0.0                    0.0
# ...                ...               ...                    ...
# 103069             0.0               0.0                    0.0
# 103070             0.0               0.0                    0.0
# 103071             0.0               0.0                    0.0
# 103072             0.0               0.0                    0.0
# 103073             0.0               0.0                    0.0
#
#        product_volume  product_price  product_comment_count product_brand  \
# 0             100 گرم          12000                      0           پاک
# 1             200 گرم          29900                      0          کاله
# 2             200 گرم          23500                      0          کاله
# 3             یک لیتر          30000                      0          میهن
# 4             350 گرم          39900                      0          کاله
# ...               ...            ...                    ...           ...
# 103069        350 گرم          45000                      0          کاله
# 103070        یک لیتر          20000                      0        می ماس
# 103071      2 کیلوگرم          55000                      0           پاک
# 103072    1.8 کیلوگرم          58900                      0          کاله
# 103073        500 گرم          18200                      0  مزرعه ماهشام
#
#         product_stock product_category           product_store_name  \
# 0                 4.0             خامه  سوپرمارکت زرفام (تهرانپارس)
# 1                 6.0             پنیر  سوپرمارکت زرفام (تهرانپارس)
# 2                59.0             خامه  سوپرمارکت زرفام (تهرانپارس)
# 3                40.0              شیر  سوپرمارکت زرفام (تهرانپارس)
# 4                21.0             پنیر  سوپرمارکت زرفام (تهرانپارس)
# ...               ...              ...                          ...
# 103069           56.0             پنیر    اکسپرس مارکت (سعادت آباد)
# 103070           11.0              شیر    اکسپرس مارکت (سعادت آباد)
# 103071            2.0             ماست    اکسپرس مارکت (سعادت آباد)
# 103072           16.0             ماست    اکسپرس مارکت (سعادت آباد)
# 103073            2.0             ماست    اکسپرس مارکت (سعادت آباد)
#
#        product_store_code
# 0                  0962dy
# 1                  0962dy
# 2                  0962dy
# 3                  0962dy
# 4                  0962dy
# ...                   ...
# 103069             pzk621
# 103070             pzk621
# 103071             pzk621
# 103072             pzk621
# 103073             pzk621
#
# [103074 rows x 13 columns]
