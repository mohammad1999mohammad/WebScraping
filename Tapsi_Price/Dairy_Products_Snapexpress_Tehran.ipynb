# %%
import requests
import json
import numpy as np
import pandas as pd
import time

# %%
final_list = []

location_stores = []

for lat in range(3590,3540,-2):
    
    for lon in range(5088,5187,3):
        
#         print('lat : ' , lat/100 , 'lon : ' , lon/100)
                
        location_stores_base_url = 'https://api.snapp.express/mobile/v3/restaurant/vendors-list?lat={}&long={}'.format(lat/100,lon/100)
        
        location_stores_base_dict = {}
        
        j=1
        
        while ((j<7) and (location_stores_base_dict=={})):
            
            try:
                location_stores_base_dict = json.loads((requests.get(location_stores_base_url,timeout=4)).text)
            except:
                j=j+1
        
#         print(location_stores_base_dict)
        
        if(location_stores_base_dict != {}):
            
            try:
                stores_count = location_stores_base_dict['data']['count']
            except:
                stores_count = 0
                
            page = 0       
            
            i = 0          
            
            while(i < stores_count):
                
                location_stores_url = 'https://api.snapp.express/mobile/v3/restaurant/vendors-list?lat={}&long={}&page={}&page_size={}'.format(lat/100, lon/100, page, 20)

                items_list = []
                
                k=1
                
                while ((k<7) and (items_list==[])):
                    
                    try:
                        items_list = (json.loads((requests.get(location_stores_url,timeout=4)).text))['data']['finalResult']
                    except:
                        k=k+1
                        
                if(items_list != []):
                    
                    for item in items_list:

                        if(item['type']=='VENDOR'):

                            i = i+1

                            store_dict = {}

                            try:
                                store_dict['store_id'] = item['data']['id']
                            except:
                                store_dict['store_id'] = '---'
                            try:
                                store_dict['store_code'] = item['data']['vendorCode']
                            except:
                                store_dict['store_code'] = '---'
                            try:
                                store_dict['store_type'] = item['data']['vendorTypeTitle']
                            except:
                                store_dict['store_type'] = '---'
                            try:
                                store_dict['store_name'] = item['data']['title']
                            except:
                                store_dict['store_name'] = '---'
                            try:
                                store_dict['store_rate_five'] = item['data']['rate']
                            except:
                                store_dict['store_rate_five'] = '---'
                            try:
                                store_dict['store_tax'] = item['data']['tax']
                            except:
                                store_dict['store_tax'] = '---'
                            try:
                                store_dict['store_service_fee'] = item['data']['serviceFee']
                            except:
                                store_dict['store_service_fee'] = '---'
                            try:
                                store_dict['store_discount'] = item['data']['discount']
                            except:
                                store_dict['store_discount'] = '---'
                            try:
                                store_dict['store_open'] = item['data']['isOpen']
                            except:
                                store_dict['store_open'] = '---'
                            try:
                                store_dict['store_min_price_order'] = item['data']['minOrder']
                            except:
                                store_dict['store_min_price_order'] = '---'
                            try:
                                store_dict['store_address'] = item['data']['address']
                            except:
                                store_dict['store_address'] = '---'
                            try:
                                store_dict['store_phone'] = item['data']['phone']
                            except:
                                store_dict['store_phone'] = '---'
                            try:
                                store_dict['store_location_lat'] = item['data']['lat']
                            except:
                                store_dict['store_location_lat'] = '---'
                            try:
                                store_dict['store_location_lon'] = item['data']['lon']
                            except:
                                store_dict['store_location_lon'] = '---'
                            try:
                                store_dict['store_priority'] = item['data']['priority']
                            except:
                                store_dict['store_priority'] = '---'
                            try:
                                store_dict['store_city'] = item['data']['city']
                            except:
                                store_dict['store_city'] = '---'
                            try:
                                store_dict['store_area'] = item['data']['area']
                            except:
                                store_dict['store_area'] = '---'
                            try:
                                store_dict['store_comment_count'] = item['data']['commentCount']
                            except:
                                store_dict['store_comment_count'] = '---'
                            try:
                                store_dict['store_vote_count'] = item['data']['voteCount']
                            except:
                                store_dict['store_vote_count'] = '---'
                            try:
                                store_dict['store_container_fee'] = item['data']['containerFee']
                            except:
                                store_dict['store_container_fee'] = '---'
                            try:
                                store_dict['store_discount_for_view'] = item['data']['discountValueForView']
                            except:
                                store_dict['store_discount_for_view'] = '---'
                            try:
                                store_dict['store_budget_class'] = item['data']['budgetClass']
                            except:
                                store_dict['store_budget_class'] = '---'
                            try:
                                store_dict['store_delivery_fee'] = item['data']['deliveryFee']
                            except:
                                store_dict['store_delivery_fee'] = '---'
                            try:
                                store_dict['store_coupon_count'] = item['data']['coupon_count']
                            except:
                                store_dict['store_coupon_count'] = '---'
                            try:
                                store_dict['store_best_coupon'] = item['data']['best_coupon']
                            except:
                                store_dict['store_best_coupon'] = '---'
                            try:
                                store_dict['store_delivery_fee_discount'] = item['data']['deliveryFeeDiscount']
                            except:
                                store_dict['store_delivery_fee_discount'] = '---'

                            location_stores.append(store_dict)
                            
            page = page + 1

# %%
len(location_stores)
# Out:
# 1712

# %%
stores_df = pd.DataFrame(location_stores)

# %%
stores_df.to_excel('stores_df.xlsx')

# %%
stores_df.drop_duplicates().to_excel('stores_df_2.xlsx')

# %%
stores_df.sort_values("store_code", inplace=True)
stores_df.drop_duplicates(subset="store_code",keep='last', inplace=True)
stores_df.to_excel('stores_df_final.xlsx')

# %%
location_stores = stores_df.to_dict('records')

# %%
len(location_stores)
# Out:
# 719

# %%
def extract_type(x):
    
    if('پنیر' in x.split(' ')):
        return 'پنیر'
    elif('شیر' in x.split(' ')):
        return 'شیر'
    elif('ماست' in x.split(' ')):
        return 'ماست'
    elif('دوغ' in x.split(' ')):
        return 'دوغ'
    elif('کره' in x.split(' ')):
        return 'کره'
    elif('خامه' in x.split(' ')):
        return 'خامه'
    elif('کشک' in x.split(' ')):
        return 'کشک'
    elif('بستنی' in x.split(' ')):
        return 'بستنی'
    else:
        return 'سایر'

# %%
dairy_id = 1032

products = []

for store in location_stores:

    store_code = store['store_code']
    
    print(store_code)

    products_base_url = 'https://api.snapp.express/product-list/{}/vendor/{}?page=0&size=10'.format(dairy_id, store_code)

    number_of_products = 0
    
    j = 1
    
    while ((j<7) and (number_of_products == 0)):
        try:
            number_of_products = json.loads(requests.get(products_base_url,timeout=3).text)["data"]["count"]
        except:
            j = j+1

    # print(number_of_products)

    size = 50

    for page in range(0, (number_of_products//size)+1):

        products_url = 'https://api.snapp.express/product-list/{}/vendor/{}?page={}&size={}'.format(dairy_id, store_code, page, size)

        products_list = []

#         print(products_url)
        
        k = 1
    
        while ((k<7) and (products_list == [])):
            try:
                products_list = (json.loads(requests.get(products_url,timeout=3).text))["data"]["finalResult"]
            except:
                k = k+1

        # products_list = (json.loads(requests.get(products_url).text))["data"]["finalResult"]

        for product in products_list:

            product_dict = {}

            try:
                product_dict['product_id'] = product['id']
            except:
                product_dict['product_id'] = '---'
            try:
                product_dict['product_name'] = product['data']['title']
            except:
                product_dict['product_name'] = '---'
            try:
                product_dict['product_discount_rate'] = product['data']['discount_ratio']
            except:
                product_dict['product_discount_rate'] = '---'
            try:
                product_dict['product_discount'] = product['data']['discount']
            except:
                product_dict['product_discount'] = '---'
            try:
                product_dict['product_main_price'] = product['data']['price']
            except:
                product_dict['product_main_price'] = '---'
            try:
                product_dict['product_sale_price'] = (product['data']['price']) - (product['data']['discount'])
            except:
                product_dict['product_sale_price'] = '---'
            try:
                product_dict['product_brand'] = product['data']['brand']
            except:
                product_dict['product_brand'] = '---'
            try:
                product_dict['product_category'] = extract_type(product_dict['product_name'])
            except:
                product_dict['product_category'] = '---'
            try:
                product_dict['product_stock'] = product['data']['stock']
            except:
                product_dict['product_stock'] = '---'
            try:
                product_dict['product_volume'] = product['data']['description']
            except:
                product_dict['product_volume'] = '---'
            try:
                product_dict['product_rating'] = round(product['data']['rating'], 2)*100
            except:
                product_dict['product_rating'] = '---'
            try:
                product_dict['product_comment_count'] = product['data']['comment_count']
            except:
                product_dict['product_comment_count'] = '---'
            try:
                product_dict['product_store_name'] = store['store_name']
            except:
                product_dict['product_store_name'] = '---'
            try:
                product_dict['product_store_code'] = store['store_code']
            except:
                product_dict['product_store_code'] = '---'

            products.append(product_dict)
# Out:
# 0962dy
# 09746y
# 09748n
# 097646
# 097j76
# 097o9d
# 097w8n
# 097xxy
# 097z6q
# 099y46
# 09e41k
# 09e48d
# 09e4ky
# 09e4ld
# 09e4wq
# 09e6qd
# 09e6qn
# 09ex2k
# 09ex6q
# 09ex7q
# 09exed
# 09exvy
# 09exwq
# 09j5d6
# 09j5ky
# 09j5m6
# 09j5z6
# 09jko6
# 09jkyd
# 09jvkq
# 09wdnk
# 09y64y
# 0g96m2
# 0gglor
# 0ggn4x
# 0ggn5n
# 0ggn92
# 0ggz5q
# 0gkl7n
# 0gklg2
# 0gklgx
# 0gklkx
# 0gkll2
# 0gkllr
# 0gklqn
# 0gkly2
# 0gknlr
# 0gknr2
# 0gknxq
# 0gkny2
# 0gko4m
# 0gkog2
# 0gkonr
# 0god2n
# 0grn7q
# 0gz51q
# 0gz55r
# 0gz58n
# 0gz5er
# 0gz5zm
# 0gz872
# 0gzdmx
# 0gzk5q
# 0gzonr
# 0gzw9m
# 0gzwjm
# 0gzwjq
# 0gzwmn
# 0gzwyx
# 0j24x6
# 0j27wg
# 0j2nv9
# 0j45e6
# 0j4e5g
# 0j4e6g
# 0j4ne9
# 0j4yq6
# 0jgdnr
# 0jgdrg
# 0jgv2g
# 0jgvl9
# 0jgvwv
# 0jgvx9
# 0jje2g
# 0jjedv
# 0jjerr
# 0jjeyr
# 0jjn66
# 0jjy86
# 0jjyx9
# 0jm4n9
# 0l2yqk
# 0l6xen
# 0l8679
# 0l8er9
# 0l8mdk
# 0ld44k
# 0ldq4k
# 0ldq9k
# 0ldqm9
# 0ldqwj
# 0ldv9k
# 0ldvvk
# 0ldwyz
# 0lekxk
# 0lgxy9
# 0lj21n
# 0lj2re
# 0lj2vk
# 0ljn6z
# 0lm44k
# 0lm82j
# 0lme5z
# 0lmn9j
# 0lmx49
# 0m1e9o
# 0m1eor
# 0m1l7r
# 0m1lry
# 0m1lwq
# 0m1lxr
# 0m1rzo
# 0m1w9o
# 0m1wey
# 0m1wxv
# 0m919o
# 0m9e7r
# 0m9eqr
# 0m9m1q
# 0m9o2q
# 0mje2z
# 0mje5r
# 0mje6q
# 0mje7z
# 0mjekr
# 0mjeny
# 0mjl1v
# 0mjl7z
# 0mjllo
# 0mjlnq
# 0mjlwo
# 0mjlyv
# 0mm1wy
# 0mmxvo
# 0mmz7r
# 0my5ov
# 0my67z
# 0my69r
# 0mynnq
# 0myr4r
# 0myr5r
# 0myr7z
# 0myr8y
# 0myrdq
# 0myrgy
# 0myrrq
# 0myrzv
# 0myzmo
# 0ndvor
# 0njgn6
# 0njgw8
# 0njgzv
# 0njl5v
# 0njl62
# 0njlg8
# 0njll8
# 0njn4z
# 0njn7z
# 0njn92
# 0njnvr
# 0njny2
# 0nq9dv
# 0nqk16
# 0nqkdz
# 0nqler
# 0nqlv8
# 0nqnd8
# 0nqnl2
# 0nqo22
# 0nqvxv
# 0nrge8
# 0nv52r
# 0nv81z
# 0nv862
# 0nv8m6
# 0nv8wr
# 0nv8y6
# 0nv8zv
# 0nvm22
# 0nvm5v
# 0nvmev
# 0nvmwr
# 0nvmy6
# 0nwerz
# 0nwqj8
# 0nwwl2
# 0q165w
# 0q16y9
# 0q1o6w
# 0q1o7d
# 0q1y4y
# 0q1y7d
# 0q1y9y
# 0q1ygd
# 0q1ynd
# 0q1yqx
# 0q1yz9
# 0q5m4y
# 0q5o9y
# 0q5ojx
# 0qd682
# 0qdeyx
# 0qe6y9
# 0qez9d
# 0ql2zw
# 0qlj1y
# 0qlje2
# 0qljm9
# 0qljnx
# 0qljwx
# 0qljxy
# 0qlz29
# 0qlzly
# 0qlzm9
# 0qr5g2
# 0rj5qz
# 0ro14v
# 0ro17o
# 0ro1l9
# 0rokk9
# 0rokrz
# 0ror4v
# 0rorl9
# 0rq5wo
# 0rq5xz
# 0rq5z8
# 0rqjyz
# 0rqmjz
# 0rqmk9
# 0rqmr9
# 0rqmvz
# 0rqmz8
# 0rv2xv
# 0rvdvv
# 0rveg1
# 0rx229
# 0rx5n1
# 0rx5r8
# 0rxnrv
# 0rxw98
# 0rye1o
# 0rym6o
# 0ryxj8
# 0ryyro
# 0w428g
# 0w4w7g
# 0w917g
# 0w9l1q
# 0wd2rz
# 0wq528
# 0wq5lz
# 0wq5xz
# 0wq5zg
# 0wqd1g
# 0wqd2v
# 0wqdlz
# 0wqdv8
# 0wqedz
# 0wqezq
# 0wwl1g
# 0wwl65
# 0wwldq
# 0wwljv
# 0wwllz
# 0wwlr5
# 0wwlv5
# 0wwlwg
# 0wwq7g
# 0wwxdq
# 0wwxo8
# 0wwxwv
# 0wz61v
# 0wzd2g
# 0wzd6v
# 0wzdmv
# 0y966g
# 0y976g
# 0y97km
# 0y9n7d
# 0y9o5y
# 0y9o6g
# 0y9o7g
# 0y9o8r
# 0y9o9n
# 0y9ody
# 0y9oer
# 0y9oqy
# 0yg1qy
# 0yg1wn
# 0yg1xm
# 0ygy6g
# 0ygykd
# 0yj92d
# 0yjd7m
# 0yjr2d
# 0yjrwd
# 0ykwem
# 0yryor
# 0yvmzr
# 314mm2
# 314vd7
# 31j8lw
# 31l564
# 31q624
# 31q662
# 31q697
# 31q6jw
# 31q6ky
# 31q6y7
# 31q6zk
# 31qom4
# 31qon7
# 31qowk
# 31x1n2
# 31x25k
# 31x2ew
# 31x2q4
# 31xrwy
# 31z287
# 31z2d7
# 31z2gk
# 31z2l4
# 31zmww
# 31zv62
# 31zv87
# 31zvo2
# 321y82
# 322r45
# 32mew2
# 32q85l
# 32q87q
# 32q8g5
# 32ql1e
# 32ql7q
# 32qldl
# 32qlg5
# 32qlj2
# 32qlqe
# 32qlvl
# 32qlwl
# 32qlxe
# 32r6o5
# 32r7ne
# 32rnw2
# 32rogd
# 32x9de
# 32xlwd
# 32xmm2
# 32xqxl
# 32xxwe
# 32xyl2
# 32z62q
# 32z682
# 32z6kd
# 32z72q
# 32z7jl
# 32z7n5
# 32z7qe
# 32z7xq
# 32zm62
# 32zm9e
# 3754x2
# 3756e2
# 375j4g
# 37o21g
# 37o2l2
# 37o2mm
# 37o2om
# 37o759
# 37o76m
# 37o799
# 37o7gg
# 37o7kn
# 37o7nn
# 37o7o9
# 37o7q2
# 37o7vg
# 37odd2
# 37r4d2
# 37r4gg
# 37r4jx
# 37r4yx
# 37rjgg
# 37rjyx
# 37rx5x
# 37rx69
# 37rxo9
# 37ww2n
# 37xw1x
# 37y94n
# 37yqo9
# 3d58mx
# 3d71xn
# 3d7667
# 3d7j47
# 3d7jvd
# 3d7jwx
# 3d7jyg
# 3d7q5w
# 3d7w9d
# 3d7x1x
# 3d7x2x
# 3d7x67
# 3d7xdx
# 3d7xen
# 3d7xng
# 3d7xqw
# 3d7xrd
# 3d7xvd
# 3d7xzg
# 3de58d
# 3de5l7
# 3de5rw
# 3del5w
# 3delen
# 3delkn
# 3deq6g
# 3deqon
# 3dm1ox
# 3dme5x
# 3dmkyw
# 3dml6g
# 3dmled
# 3dq827
# 3dqwzw
# 3dr45w
# 3dr6on
# 3drnmd
# 3dvr5g
# 3dvyn7
# 3e5zy5
# 3e966v
# 3ee5lm
# 3ee5nv
# 3ee5vj
# 3ee5z2
# 3ee682
# 3ee6q5
# 3eeljj
# 3eelkm
# 3eeloo
# 3eq4qj
# 3eq6lv
# 3ew6lm
# 3ez7dv
# 3ez7go
# 3ez7jj
# 3ez7km
# 3ez7w2
# 3ez7xv
# 3eze12
# 3ezk22
# 3ezk55
# 3ezk65
# 3ezk8o
# 3ezknm
# 3ezkyv
# 3ezkzo
# 3k9m5k
# 3k9mlo
# 3k9mmn
# 3k9mqg
# 3k9y1q
# 3k9yqg
# 3kj6kk
# 3kj6ln
# 3kj6nn
# 3kj6wo
# 3kjl9j
# 3kjleg
# 3kjlgg
# 3kjlmn
# 3kjlvo
# 3kjneg
# 3kjnyn
# 3klmrk
# 3kolzk
# 3kon2j
# 3konqk
# 3kv66g
# 3kv92n
# 3kvoek
# 3x1974
# 3x2gvw
# 3x2xl6
# 3x2ygy
# 3x5zkw
# 3xgekw
# 3xgenw
# 3xgeq9
# 3xger2
# 3xgr6w
# 3xgyjy
# 3xgz22
# 3xgz66
# 3xgzdy
# 3xgze4
# 3xgzl9
# 3xgzx6
# 3xrz69
# 3xwdg2
# 3xwdo6
# 3xwdv6
# 3xwdy4
# 3xwj2y
# 3xwj5y
# 3xwj8w
# 3xwjg2
# 3xwynw
# 3xwyw2
# 3xwyx6
# p428jy
# p42lkj
# p47ler
# p47o9y
# p4g85x
# p4gxvx
# p4jov5
# p4qd9r
# p4qklj
# p4qndj
# p4qney
# p4qngr
# p4qnyj
# p4qo95
# p4qodj
# p4qoej
# p4qoky
# p4qox5
# p4qozj
# p4rn4x
# p4z48j
# p4z4v5
# p4z4yj
# p4zlnx
# p4zlwx
# p4zlx5
# p4zryr
# p557xv
# p559ge
# p55o6e
# p55q7w
# p5q45v
# p5q4dx
# p5q4ow
# p5q4wv
# p5q4zn
# p5qgxj
# p5qk2n
# p5qlqe
# p5qx8e
# p5qxke
# p5qxyn
# p5r8dj
# p5rj7v
# p5ry8j
# p5w4vn
# p5z24j
# p5z2ex
# p5z2ke
# p5z2xj
# p5z2zv
# p5zj2j
# p5zjoj
# p5zokn
# p5zomx
# p5zoqv
# p5zovn
# p627vn
# p62o76
# p6746w
# p674gn
# p674wo
# p674xg
# p67d9o
# p6dv16
# p6j6n6
# p6omko
# p6r1ro
# p6re4n
# p6rege
# p6reno
# p6reqg
# p6rexn
# p6rvnw
# p6rx96
# p6rxe6
# p6rxre
# p6rxx6
# p6rxyg
# p6rxze
# p6z47w
# p6z496
# p6z4on
# p6z4rw
# p6zde6
# p6zdve
# p6zdx6
# p8487g
# p84k8g
# p84kz2
# p8751g
# p875l5
# p87612
# p878dm
# p87okg
# p87v7r
# p8d51g
# p8djjr
# p8e52g
# p8e56m
# p8e58g
# p8e5kr
# p8e5lg
# p8e5o5
# p8exmg
# p8exnm
# p8exyr
# p8g7v2
# p8gl4m
# p8oj2m
# p8ojmg
# p8ojr2
# p8ok1m
# p8okd5
# p8okjr
# p8oko5
# po658q
# po6l5o
# po6le8
# po6lnv
# po6lwj
# po6n6q
# po6n8k
# po6nn8
# po6nv8
# po6nyq
# po6nzv
# po9e8j
# po9qzk
# pogqjq
# poj91o
# poj9mk
# poj9n8
# poj9vk
# poj9wo
# pojq5o
# pojq7j
# pojqvk
# pojqyq
# pojzgv
# poo2yo
# poo5lo
# pooj4v
# pooq2j
# poowqq
# porgzk
# pork88
# poydrq
# poyn1o
# pvezz5
# pvj961
# pvl67x
# pvl6ev
# pvl6mx
# pvl6v1
# pvl6wx
# pvln6m
# pvlnd5
# pvlnrv
# pvlny1
# pvlv9v
# pvq97x
# pvq9d5
# pvq9gm
# pvq9jv
# pvq9n5
# pvqrkd
# pvqrx5
# pvqx5d
# pvqxlv
# pz86ew
# pz86re
# pz892j
# pz8eg2
# pz8lzo
# pz8n71
# pz962o
# pz96e2
# pz96jw
# pz9e82
# pz9enw
# pz9n4w
# pz9njw
# pz9nl1
# pz9nw1
# pz9nxo
# pzd44w
# pzd45e
# pzd49e
# pzd4kj
# pzd4vj
# pzd4w1
# pzd6z1
# pzde6w
# pzdj42
# pzdjej
# pzek52
# pzk621

# %%
back = products

# %%
beverage_id = 940

for store in location_stores:

    store_code = store['store_code']
    
    print(store_code)
    
    products_base_url = 'https://newapi.snapp.express/product-list/{}/vendor/{}?page=0&size=10&categories=82'.format(beverage_id, store_code)

    number_of_products = 0
    
    j = 1
    
    while ((j<7) and (number_of_products == 0)):
        try:
            number_of_products = json.loads(requests.get(products_base_url,timeout=3).text)["data"]["count"]
        except:
            j = j+1

    # print(number_of_products)

    size = 30

    for page in range(0, (number_of_products//size)+1):

        products_url = 'https://newapi.snapp.express/product-list/{}/vendor/{}?page={}&size={}&categories=82'.format(beverage_id, store_code, page, size)

        products_list = []

#         print(products_url)
        
        k = 1
    
        while ((k<7) and (products_list == [])):
            try:
                products_list = (json.loads(requests.get(products_url,timeout=3).text))["data"]["finalResult"]
            except:
                k = k+1

        # products_list = (json.loads(requests.get(products_url).text))["data"]["finalResult"]

        for product in products_list:

            product_dict = {}

            try:
                product_dict['product_id'] = product['id']
            except:
                product_dict['product_id'] = '---'
            try:
                product_dict['product_name'] = product['data']['title']
            except:
                product_dict['product_name'] = '---'
            try:
                product_dict['product_discount_rate'] = product['data']['discount_ratio']
            except:
                product_dict['product_discount_rate'] = '---'
            try:
                product_dict['product_discount'] = product['data']['discount']
            except:
                product_dict['product_discount'] = '---'
            try:
                product_dict['product_main_price'] = product['data']['price']
            except:
                product_dict['product_main_price'] = '---'
            try:
                product_dict['product_sale_price'] = (product['data']['price']) - (product['data']['discount'])
            except:
                product_dict['product_sale_price'] = '---'
            try:
                product_dict['product_brand'] = product['data']['brand']
            except:
                product_dict['product_brand'] = '---'
            try:
                product_dict['product_category'] = extract_type(product_dict['product_name'])
            except:
                product_dict['product_category'] = '---'
            try:
                product_dict['product_stock'] = product['data']['stock']
            except:
                product_dict['product_stock'] = '---'
            try:
                product_dict['product_volume'] = product['data']['description']
            except:
                product_dict['product_volume'] = '---'
            try:
                product_dict['product_rating'] = round(product['data']['rating'], 2)*100
            except:
                product_dict['product_rating'] = '---'
            try:
                product_dict['product_comment_count'] = product['data']['comment_count']
            except:
                product_dict['product_comment_count'] = '---'
            try:
                product_dict['product_store_name'] = store['store_name']
            except:
                product_dict['product_store_name'] = '---'
            try:
                product_dict['product_store_code'] = store['store_code']
            except:
                product_dict['product_store_code'] = '---'

            products.append(product_dict)
# Out:
# 0962dy
# 09746y
# 09748n
# 097646
# 097j76
# 097o9d
# 097w8n
# 097xxy
# 097z6q
# 099y46
# 09e41k
# 09e48d
# 09e4ky
# 09e4ld
# 09e4wq
# 09e6qd
# 09e6qn
# 09ex2k
# 09ex6q
# 09ex7q
# 09exed
# 09exvy
# 09exwq
# 09j5d6
# 09j5ky
# 09j5m6
# 09j5z6
# 09jko6
# 09jkyd
# 09jvkq
# 09wdnk
# 09y64y
# 0g96m2
# 0gglor
# 0ggn4x
# 0ggn5n
# 0ggn92
# 0ggz5q
# 0gkl7n
# 0gklg2
# 0gklgx
# 0gklkx
# 0gkll2
# 0gkllr
# 0gklqn
# 0gkly2
# 0gknlr
# 0gknr2
# 0gknxq
# 0gkny2
# 0gko4m
# 0gkog2
# 0gkonr
# 0god2n
# 0grn7q
# 0gz51q
# 0gz55r
# 0gz58n
# 0gz5er
# 0gz5zm
# 0gz872
# 0gzdmx
# 0gzk5q
# 0gzonr
# 0gzw9m
# 0gzwjm
# 0gzwjq
# 0gzwmn
# 0gzwyx
# 0j24x6
# 0j27wg
# 0j2nv9
# 0j45e6
# 0j4e5g
# 0j4e6g
# 0j4ne9
# 0j4yq6
# 0jgdnr
# 0jgdrg
# 0jgv2g
# 0jgvl9
# 0jgvwv
# 0jgvx9
# 0jje2g
# 0jjedv
# 0jjerr
# 0jjeyr
# 0jjn66
# 0jjy86
# 0jjyx9
# 0jm4n9
# 0l2yqk
# 0l6xen
# 0l8679
# 0l8er9
# 0l8mdk
# 0ld44k
# 0ldq4k
# 0ldq9k
# 0ldqm9
# 0ldqwj
# 0ldv9k
# 0ldvvk
# 0ldwyz
# 0lekxk
# 0lgxy9
# 0lj21n
# 0lj2re
# 0lj2vk
# 0ljn6z
# 0lm44k
# 0lm82j
# 0lme5z
# 0lmn9j
# 0lmx49
# 0m1e9o
# 0m1eor
# 0m1l7r
# 0m1lry
# 0m1lwq
# 0m1lxr
# 0m1rzo
# 0m1w9o
# 0m1wey
# 0m1wxv
# 0m919o
# 0m9e7r
# 0m9eqr
# 0m9m1q
# 0m9o2q
# 0mje2z
# 0mje5r
# 0mje6q
# 0mje7z
# 0mjekr
# 0mjeny
# 0mjl1v
# 0mjl7z
# 0mjllo
# 0mjlnq
# 0mjlwo
# 0mjlyv
# 0mm1wy
# 0mmxvo
# 0mmz7r
# 0my5ov
# 0my67z
# 0my69r
# 0mynnq
# 0myr4r
# 0myr5r
# 0myr7z
# 0myr8y
# 0myrdq
# 0myrgy
# 0myrrq
# 0myrzv
# 0myzmo
# 0ndvor
# 0njgn6
# 0njgw8
# 0njgzv
# 0njl5v
# 0njl62
# 0njlg8
# 0njll8
# 0njn4z
# 0njn7z
# 0njn92
# 0njnvr
# 0njny2
# 0nq9dv
# 0nqk16
# 0nqkdz
# 0nqler
# 0nqlv8
# 0nqnd8
# 0nqnl2
# 0nqo22
# 0nqvxv
# 0nrge8
# 0nv52r
# 0nv81z
# 0nv862
# 0nv8m6
# 0nv8wr
# 0nv8y6
# 0nv8zv
# 0nvm22
# 0nvm5v
# 0nvmev
# 0nvmwr
# 0nvmy6
# 0nwerz
# 0nwqj8
# 0nwwl2
# 0q165w
# 0q16y9
# 0q1o6w
# 0q1o7d
# 0q1y4y
# 0q1y7d
# 0q1y9y
# 0q1ygd
# 0q1ynd
# 0q1yqx
# 0q1yz9
# 0q5m4y
# 0q5o9y
# 0q5ojx
# 0qd682
# 0qdeyx
# 0qe6y9
# 0qez9d
# 0ql2zw
# 0qlj1y
# 0qlje2
# 0qljm9
# 0qljnx
# 0qljwx
# 0qljxy
# 0qlz29
# 0qlzly
# 0qlzm9
# 0qr5g2
# 0rj5qz
# 0ro14v
# 0ro17o
# 0ro1l9
# 0rokk9
# 0rokrz
# 0ror4v
# 0rorl9
# 0rq5wo
# 0rq5xz
# 0rq5z8
# 0rqjyz
# 0rqmjz
# 0rqmk9
# 0rqmr9
# 0rqmvz
# 0rqmz8
# 0rv2xv
# 0rvdvv
# 0rveg1
# 0rx229
# 0rx5n1
# 0rx5r8
# 0rxnrv
# 0rxw98
# 0rye1o
# 0rym6o
# 0ryxj8
# 0ryyro
# 0w428g
# 0w4w7g
# 0w917g
# 0w9l1q
# 0wd2rz
# 0wq528
# 0wq5lz
# 0wq5xz
# 0wq5zg
# 0wqd1g
# 0wqd2v
# 0wqdlz
# 0wqdv8
# 0wqedz
# 0wqezq
# 0wwl1g
# 0wwl65
# 0wwldq
# 0wwljv
# 0wwllz
# 0wwlr5
# 0wwlv5
# 0wwlwg
# 0wwq7g
# 0wwxdq
# 0wwxo8
# 0wwxwv
# 0wz61v
# 0wzd2g
# 0wzd6v
# 0wzdmv
# 0y966g
# 0y976g
# 0y97km
# 0y9n7d
# 0y9o5y
# 0y9o6g
# 0y9o7g
# 0y9o8r
# 0y9o9n
# 0y9ody
# 0y9oer
# 0y9oqy
# 0yg1qy
# 0yg1wn
# 0yg1xm
# 0ygy6g
# 0ygykd
# 0yj92d
# 0yjd7m
# 0yjr2d
# 0yjrwd
# 0ykwem
# 0yryor
# 0yvmzr
# 314mm2
# 314vd7
# 31j8lw
# 31l564
# 31q624
# 31q662
# 31q697
# 31q6jw
# 31q6ky
# 31q6y7
# 31q6zk
# 31qom4
# 31qon7
# 31qowk
# 31x1n2
# 31x25k
# 31x2ew
# 31x2q4
# 31xrwy
# 31z287
# 31z2d7
# 31z2gk
# 31z2l4
# 31zmww
# 31zv62
# 31zv87
# 31zvo2
# 321y82
# 322r45
# 32mew2
# 32q85l
# 32q87q
# 32q8g5
# 32ql1e
# 32ql7q
# 32qldl
# 32qlg5
# 32qlj2
# 32qlqe
# 32qlvl
# 32qlwl
# 32qlxe
# 32r6o5
# 32r7ne
# 32rnw2
# 32rogd
# 32x9de
# 32xlwd
# 32xmm2
# 32xqxl
# 32xxwe
# 32xyl2
# 32z62q
# 32z682
# 32z6kd
# 32z72q
# 32z7jl
# 32z7n5
# 32z7qe
# 32z7xq
# 32zm62
# 32zm9e
# 3754x2
# 3756e2
# 375j4g
# 37o21g
# 37o2l2
# 37o2mm
# 37o2om
# 37o759
# 37o76m
# 37o799
# 37o7gg
# 37o7kn
# 37o7nn
# 37o7o9
# 37o7q2
# 37o7vg
# 37odd2
# 37r4d2
# 37r4gg
# 37r4jx
# 37r4yx
# 37rjgg
# 37rjyx
# 37rx5x
# 37rx69
# 37rxo9
# 37ww2n
# 37xw1x
# 37y94n
# 37yqo9
# 3d58mx
# 3d71xn
# 3d7667
# 3d7j47
# 3d7jvd
# 3d7jwx
# 3d7jyg
# 3d7q5w
# 3d7w9d
# 3d7x1x
# 3d7x2x
# 3d7x67
# 3d7xdx
# 3d7xen
# 3d7xng
# 3d7xqw
# 3d7xrd
# 3d7xvd
# 3d7xzg
# 3de58d
# 3de5l7
# 3de5rw
# 3del5w
# 3delen
# 3delkn
# 3deq6g
# 3deqon
# 3dm1ox
# 3dme5x
# 3dmkyw
# 3dml6g
# 3dmled
# 3dq827
# 3dqwzw
# 3dr45w
# 3dr6on
# 3drnmd
# 3dvr5g
# 3dvyn7
# 3e5zy5
# 3e966v
# 3ee5lm
# 3ee5nv
# 3ee5vj
# 3ee5z2
# 3ee682
# 3ee6q5
# 3eeljj
# 3eelkm
# 3eeloo
# 3eq4qj
# 3eq6lv
# 3ew6lm
# 3ez7dv
# 3ez7go
# 3ez7jj
# 3ez7km
# 3ez7w2
# 3ez7xv
# 3eze12
# 3ezk22
# 3ezk55
# 3ezk65
# 3ezk8o
# 3ezknm
# 3ezkyv
# 3ezkzo
# 3k9m5k
# 3k9mlo
# 3k9mmn
# 3k9mqg
# 3k9y1q
# 3k9yqg
# 3kj6kk
# 3kj6ln
# 3kj6nn
# 3kj6wo
# 3kjl9j
# 3kjleg
# 3kjlgg
# 3kjlmn
# 3kjlvo
# 3kjneg
# 3kjnyn
# 3klmrk
# 3kolzk
# 3kon2j
# 3konqk
# 3kv66g
# 3kv92n
# 3kvoek
# 3x1974
# 3x2gvw
# 3x2xl6
# 3x2ygy
# 3x5zkw
# 3xgekw
# 3xgenw
# 3xgeq9
# 3xger2
# 3xgr6w
# 3xgyjy
# 3xgz22
# 3xgz66
# 3xgzdy
# 3xgze4
# 3xgzl9
# 3xgzx6
# 3xrz69
# 3xwdg2
# 3xwdo6
# 3xwdv6
# 3xwdy4
# 3xwj2y
# 3xwj5y
# 3xwj8w
# 3xwjg2
# 3xwynw
# 3xwyw2
# 3xwyx6
# p428jy
# p42lkj
# p47ler
# p47o9y
# p4g85x
# p4gxvx
# p4jov5
# p4qd9r
# p4qklj
# p4qndj
# p4qney
# p4qngr
# p4qnyj
# p4qo95
# p4qodj
# p4qoej
# p4qoky
# p4qox5
# p4qozj
# p4rn4x
# p4z48j
# p4z4v5
# p4z4yj
# p4zlnx
# p4zlwx
# p4zlx5
# p4zryr
# p557xv
# p559ge
# p55o6e
# p55q7w
# p5q45v
# p5q4dx
# p5q4ow
# p5q4wv
# p5q4zn
# p5qgxj
# p5qk2n
# p5qlqe
# p5qx8e
# p5qxke
# p5qxyn
# p5r8dj
# p5rj7v
# p5ry8j
# p5w4vn
# p5z24j
# p5z2ex
# p5z2ke
# p5z2xj
# p5z2zv
# p5zj2j
# p5zjoj
# p5zokn
# p5zomx
# p5zoqv
# p5zovn
# p627vn
# p62o76
# p6746w
# p674gn
# p674wo
# p674xg
# p67d9o
# p6dv16
# p6j6n6
# p6omko
# p6r1ro
# p6re4n
# p6rege
# p6reno
# p6reqg
# p6rexn
# p6rvnw
# p6rx96
# p6rxe6
# p6rxre
# p6rxx6
# p6rxyg
# p6rxze
# p6z47w
# p6z496
# p6z4on
# p6z4rw
# p6zde6
# p6zdve
# p6zdx6
# p8487g
# p84k8g
# p84kz2
# p8751g
# p875l5
# p87612
# p878dm
# p87okg
# p87v7r
# p8d51g
# p8djjr
# p8e52g
# p8e56m
# p8e58g
# p8e5kr
# p8e5lg
# p8e5o5
# p8exmg
# p8exnm
# p8exyr
# p8g7v2
# p8gl4m
# p8oj2m
# p8ojmg
# p8ojr2
# p8ok1m
# p8okd5
# p8okjr
# p8oko5
# po658q
# po6l5o
# po6le8
# po6lnv
# po6lwj
# po6n6q
# po6n8k
# po6nn8
# po6nv8
# po6nyq
# po6nzv
# po9e8j
# po9qzk
# pogqjq
# poj91o
# poj9mk
# poj9n8
# poj9vk
# poj9wo
# pojq5o
# pojq7j
# pojqvk
# pojqyq
# pojzgv
# poo2yo
# poo5lo
# pooj4v
# pooq2j
# poowqq
# porgzk
# pork88
# poydrq
# poyn1o
# pvezz5
# pvj961
# pvl67x
# pvl6ev
# pvl6mx
# pvl6v1
# pvl6wx
# pvln6m
# pvlnd5
# pvlnrv
# pvlny1
# pvlv9v
# pvq97x
# pvq9d5
# pvq9gm
# pvq9jv
# pvq9n5
# pvqrkd
# pvqrx5
# pvqx5d
# pvqxlv
# pz86ew
# pz86re
# pz892j
# pz8eg2
# pz8lzo
# pz8n71
# pz962o
# pz96e2
# pz96jw
# pz9e82
# pz9enw
# pz9n4w
# pz9njw
# pz9nl1
# pz9nw1
# pz9nxo
# pzd44w
# pzd45e
# pzd49e
# pzd4kj
# pzd4vj
# pzd4w1
# pzd6z1
# pzde6w
# pzdj42
# pzdjej
# pzek52
# pzk621

# %%
products_df = pd.DataFrame(products)

# %%
products_df.to_excel('products_df.xlsx')

# %%
len(products_df['product_store_code'].value_counts().index)
# Out:
# 699

# %%
col_names_product = ['کد محصول','نام محصول','نرخ تخفیف محصول','مقدار تخفیف محصول','قیمت اصلی محصول','قیمت فروش محصول','برند محصول','گروه محصول','موجودی محصول','حجم محصول','ریتینگ محصول','تعداد کامنت محصول','نام فروشگاه','کد فروشگاه','آیدی فروشگاه']

col_names_store = ['آیدی فروشگاه','کد فروشگاه','نوع فروشگاه','نام فروشگاه','نرخ ستاره فروشگاه','مالیات فروشگاه','هزینه خدمات فروشگاه','تخفیف فروشگاه','باز بودن فروشگاه','حداقل قیمت سفارش فروشگاه','آدرس فروشگاه','شماره تلفن فروشگاه','لوکیشن لت فروشگاه','لوکیشن لان فروشگاه','اولویت فروشگاه','شهر فروشگاه','منطقه فروشگاه','تعداد کامنت فروشگاه','تعداد رای فروشگاه','هزینه حمل کننده فروشگاه','تخفیف فروشگاه برای بازدبد','دسته بودجه فروشگاه','هزینه ارسال فروشگاه','تعداد کوپن فروشگاه','بهترین کوپن فروشگاه','تخفیف هزینه ارسال فروشگاه']

# %%
stores_df
# Out:
#       store_id store_code store_type                            store_name  \
# 986      35574     0962dy  سوپرمارکت           سوپرمارکت زرفام (تهرانپارس)
# 506      55926     09746y  سوپرمارکت        سوپرمارکت قایم (برادران ترابی)
# 335      56174     09748n  سوپرمارکت                         سوپرمارکت شفق
# 844      56474     097646  سوپرمارکت            سوپرمارکت شهرزاد (باغ فیض)
# 1148     59426     097j76  سوپرمارکت          سوپرمارکت شعاع (کریمخان زند)
# ...        ...        ...        ...                                   ...
# 511      97934     pzde6w  سوپرمارکت  سوپرمارکت پاسداران (شهرک شهید باقری)
# 576     110010     pzdj42  سوپرمارکت                   اکسپرس مارکت (پونک)
# 1518    109510     pzdjej  سوپرمارکت             گندم آبشار (همواره تخفیف)
# 1048     30810     pzek52  سوپرمارکت        سوپرمارکت ایرانیان (فردوس شرق)
# 636      69558     pzk621  سوپرمارکت             اکسپرس مارکت (سعادت آباد)
#
#       store_rate_five  store_tax  store_service_fee  store_discount  \
# 986               4.3        0.0                  0               0
# 506               4.8        0.0                  0               0
# 335               4.2        0.0                  0               0
# 844               4.5        0.0                  0               0
# 1148              4.0        0.0                  0               0
# ...               ...        ...                ...             ...
# 511               4.0        0.0                  0               0
# 576               4.5        NaN                  0               0
# 1518              4.3        0.0                  0               0
# 1048              4.3        0.0                  0               0
# 636               4.4        0.0                  0               0
#
#       store_open  store_min_price_order  ...       store_area  \
# 986         True                  50000  ...  تهران پارس غربی
# 506        False                  50000  ...
# 335         True                  55000  ...             دریا
# 844         True                  65000  ...          باغ فيض
# 1148        True                  55000  ...            سنائی
# ...          ...                    ...  ...              ...
# 511         True                  60000  ...       شهید باقری
# 576         True                  65000  ...             پونک
# 1518       False                  65000  ...      آبشار-دردار
# 1048        True                  65000  ...        فردوس شرق
# 636         True                  65000  ...            آسمان
#
#      store_comment_count  store_vote_count  store_container_fee  \
# 986                48886              1694                    0
# 506                52077              1642                    0
# 335                18640               467                    0
# 844                15695               533                 2200
# 1148               11597               462                    0
# ...                  ...               ...                  ...
# 511                 4174               178                    0
# 576                73820              3720                 1700
# 1518                3004               123                 2200
# 1048               51694              1676                    0
# 636               120425              5088                 1900
#
#       store_discount_for_view store_budget_class store_delivery_fee  \
# 986                        50              مناسب               9100
# 506                         0              مناسب               7900
# 335                        45              مناسب              11900
# 844                        50              مناسب               8200
# 1148                       45              مناسب               7500
# ...                       ...                ...                ...
# 511                        25              مناسب               7700
# 576                        40              مناسب               4500
# 1518                       30              مناسب               8600
# 1048                       50            به صرفه               7700
# 636                        40              مناسب               5500
#
#       store_coupon_count                          store_best_coupon  \
# 986                    0
# 506                    0
# 335                    0
# 844                    0
# 1148                   0
# ...                  ...                                        ...
# 511                    0
# 576                    1  ارسال رایگان با خرید حداقل 250 هزار تومان
# 1518                   1  ارسال رایگان با خرید حداقل 150 هزار تومان
# 1048                   0
# 636                    1  ارسال رایگان با خرید حداقل 280 هزار تومان
#
#       store_delivery_fee_discount
# 986                             0
# 506                             0
# 335                             0
# 844                             0
# 1148                            0
# ...                           ...
# 511                             0
# 576                             0
# 1518                            0
# 1048                            0
# 636                             0
#
# [719 rows x 26 columns]

# %%
code_id = stores_df[['store_code','store_id']]

# %%
code_id
# Out:
#      store_code  store_id
# 986      0962dy     35574
# 506      09746y     55926
# 335      09748n     56174
# 844      097646     56474
# 1148     097j76     59426
# ...         ...       ...
# 511      pzde6w     97934
# 576      pzdj42    110010
# 1518     pzdjej    109510
# 1048     pzek52     30810
# 636      pzk621     69558
#
# [719 rows x 2 columns]

# %%
products_df.rename(columns = {'product_store_code':'store_code'}, inplace = True)

# %%
products_df = pd.merge(products_df,code_id,on='store_code')

# %%
with pd.ExcelWriter("Products_Stores_Snapexpress_Tehran.xlsx") as writer:
    products_df.columns = col_names_product
    products_df.to_excel(writer, sheet_name="Products", index=False)
    stores_df.columns = col_names_store    
    stores_df.to_excel(writer, sheet_name='Stores', index=False)
