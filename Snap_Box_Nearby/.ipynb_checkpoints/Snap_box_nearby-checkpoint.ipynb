# %%
import requests
import json
import numpy as np
import pandas as pd
import time
import datetime

# %%
url = 'https://app.snapp-box.com/api/v1/customer/nearby_biker_locations'

# %%
df = pd.read_excel("input_data.xlsx",sheet_name = "Sheet1")

# %%
auth_token = 'eyJhbGciOiJIUzUxMiJ9.eyJjaWQiOjE5NzE3MzA3LCJjcmlkIjoiMzMzNjQ3MDAiLCJlIjoibXprbW56a21AeWFob28uY29tIiwid2UiOmZhbHNlLCJzdWIiOiIwOTExNDU5ODI4NCIsImF1dGgiOiJST0xFX0NVU1RPTUVSIiwidHlwZSI6ImN1c3RvbWVyIn0.JKdYVbt2npsgCl2wW6WiqWcHKFXRrgAAhY536M3ejpdFUqdZh_-pxlMEELu4Zj086B_EzJ20oMdavbZ6MeHXtg'

# %%
client_type = 'jek-pwa'

# %%
content_type = 'application/json'

# %%
platform = 'web'

# %%
data_list = []

for i in range(0,len(df),1):
    
    request = {}
    request['longitude'] = df['Source_long'][i]
    request['latitude'] = df['Source_lat'][i]
    request['zoom'] = str(df['zoom'][i])

    headers = {'Content-Type': content_type, 'Clienttype': client_type, 'Authorization': auth_token, 'Platform': platform}
    
    # print(request)
    response = requests.post(url, json=request, headers=headers)
    data = response.json()
    # print(data)
    for item in data:
        dictionary = {}
        # print(item['apiValue'] )
        dictionary['type'] = item['apiValue'] 
        dictionary['count'] = item['count']
        dictionary['area'] = str(df['Area_name'][i])
        dictionary['date'] = str(datetime.date.today())
        dictionary['time'] = str(datetime.datetime.now().strftime("%X"))
        data_list.append(dictionary)

# %%
data_list
# Out:
# [{'type': 'bike-without-box',
#   'count': 218,
#   'area': 'فاطمی',
#   'date': '2023-05-07',
#   'time': '17:01:28'},
#  {'type': 'bike',
#   'count': 16,
#   'area': 'فاطمی',
#   'date': '2023-05-07',
#   'time': '17:01:28'},
#  {'type': 'van',
#   'count': 70,
#   'area': 'فاطمی',
#   'date': '2023-05-07',
#   'time': '17:01:28'},
#  {'type': 'van-heavy',
#   'count': 9,
#   'area': 'فاطمی',
#   'date': '2023-05-07',
#   'time': '17:01:28'},
#  {'type': 'bike-without-box',
#   'count': 72,
#   'area': 'سعادت\u200cآباد',
#   'date': '2023-05-07',
#   'time': '17:01:28'},
#  {'type': 'bike',
#   'count': 15,
#   'area': 'سعادت\u200cآباد',
#   'date': '2023-05-07',
#   'time': '17:01:28'},
#  {'type': 'van',
#   'count': 34,
#   'area': 'سعادت\u200cآباد',
#   'date': '2023-05-07',
#   'time': '17:01:28'},
#  {'type': 'van-heavy',
#   'count': 12,
#   'area': 'سعادت\u200cآباد',
#   'date': '2023-05-07',
#   'time': '17:01:28'},
#  {'type': 'bike-without-box',
#   'count': 53,
#   'area': 'تهران پارس',
#   'date': '2023-05-07',
#   'time': '17:01:28'},
#  {'type': 'bike',
#   'count': 9,
#   'area': 'تهران پارس',
#   'date': '2023-05-07',
#   'time': '17:01:28'},
#  {'type': 'van',
#   'count': 133,
#   'area': 'تهران پارس',
#   'date': '2023-05-07',
#   'time': '17:01:28'},
#  {'type': 'van-heavy',
#   'count': 21,
#   'area': 'تهران پارس',
#   'date': '2023-05-07',
#   'time': '17:01:28'},
#  {'type': 'bike-without-box',
#   'count': 101,
#   'area': 'پاسداران',
#   'date': '2023-05-07',
#   'time': '17:01:28'},
#  {'type': 'bike',
#   'count': 17,
#   'area': 'پاسداران',
#   'date': '2023-05-07',
#   'time': '17:01:28'},
#  {'type': 'van',
#   'count': 54,
#   'area': 'پاسداران',
#   'date': '2023-05-07',
#   'time': '17:01:28'},
#  {'type': 'van-heavy',
#   'count': 18,
#   'area': 'پاسداران',
#   'date': '2023-05-07',
#   'time': '17:01:28'},
#  {'type': 'bike-without-box',
#   'count': 64,
#   'area': 'نیاوران',
#   'date': '2023-05-07',
#   'time': '17:01:29'},
#  {'type': 'bike',
#   'count': 12,
#   'area': 'نیاوران',
#   'date': '2023-05-07',
#   'time': '17:01:29'},
#  {'type': 'van',
#   'count': 25,
#   'area': 'نیاوران',
#   'date': '2023-05-07',
#   'time': '17:01:29'},
#  {'type': 'van-heavy',
#   'count': 10,
#   'area': 'نیاوران',
#   'date': '2023-05-07',
#   'time': '17:01:29'},
#  {'type': 'bike-without-box',
#   'count': 86,
#   'area': 'پیروزی',
#   'date': '2023-05-07',
#   'time': '17:01:29'},
#  {'type': 'bike',
#   'count': 8,
#   'area': 'پیروزی',
#   'date': '2023-05-07',
#   'time': '17:01:29'},
#  {'type': 'van',
#   'count': 72,
#   'area': 'پیروزی',
#   'date': '2023-05-07',
#   'time': '17:01:29'},
#  {'type': 'van-heavy',
#   'count': 18,
#   'area': 'پیروزی',
#   'date': '2023-05-07',
#   'time': '17:01:29'},
#  {'type': 'bike-without-box',
#   'count': 67,
#   'area': 'قزوین',
#   'date': '2023-05-07',
#   'time': '17:01:29'},
#  {'type': 'bike',
#   'count': 3,
#   'area': 'قزوین',
#   'date': '2023-05-07',
#   'time': '17:01:29'},
#  {'type': 'van',
#   'count': 108,
#   'area': 'قزوین',
#   'date': '2023-05-07',
#   'time': '17:01:29'},
#  {'type': 'van-heavy',
#   'count': 25,
#   'area': 'قزوین',
#   'date': '2023-05-07',
#   'time': '17:01:29'},
#  {'type': 'bike-without-box',
#   'count': 76,
#   'area': 'اندرزگو',
#   'date': '2023-05-07',
#   'time': '17:01:29'},
#  {'type': 'bike',
#   'count': 20,
#   'area': 'اندرزگو',
#   'date': '2023-05-07',
#   'time': '17:01:29'},
#  {'type': 'van',
#   'count': 39,
#   'area': 'اندرزگو',
#   'date': '2023-05-07',
#   'time': '17:01:29'},
#  {'type': 'van-heavy',
#   'count': 8,
#   'area': 'اندرزگو',
#   'date': '2023-05-07',
#   'time': '17:01:29'},
#  {'type': 'bike-without-box',
#   'count': 46,
#   'area': 'پونک',
#   'date': '2023-05-07',
#   'time': '17:01:30'},
#  {'type': 'bike',
#   'count': 8,
#   'area': 'پونک',
#   'date': '2023-05-07',
#   'time': '17:01:30'},
#  {'type': 'van',
#   'count': 49,
#   'area': 'پونک',
#   'date': '2023-05-07',
#   'time': '17:01:30'},
#  {'type': 'van-heavy',
#   'count': 23,
#   'area': 'پونک',
#   'date': '2023-05-07',
#   'time': '17:01:30'},
#  {'type': 'bike-without-box',
#   'count': 7,
#   'area': 'دریاچه چیتگر',
#   'date': '2023-05-07',
#   'time': '17:01:30'},
#  {'type': 'bike',
#   'count': 1,
#   'area': 'دریاچه چیتگر',
#   'date': '2023-05-07',
#   'time': '17:01:30'},
#  {'type': 'van',
#   'count': 12,
#   'area': 'دریاچه چیتگر',
#   'date': '2023-05-07',
#   'time': '17:01:30'},
#  {'type': 'van-heavy',
#   'count': 2,
#   'area': 'دریاچه چیتگر',
#   'date': '2023-05-07',
#   'time': '17:01:30'},
#  {'type': 'bike-without-box',
#   'count': 19,
#   'area': 'شهران',
#   'date': '2023-05-07',
#   'time': '17:01:30'},
#  {'type': 'bike',
#   'count': 2,
#   'area': 'شهران',
#   'date': '2023-05-07',
#   'time': '17:01:30'},
#  {'type': 'van',
#   'count': 33,
#   'area': 'شهران',
#   'date': '2023-05-07',
#   'time': '17:01:30'},
#  {'type': 'van-heavy',
#   'count': 18,
#   'area': 'شهران',
#   'date': '2023-05-07',
#   'time': '17:01:30'},
#  {'type': 'bike-without-box',
#   'count': 50,
#   'area': '۱۷ شهریور',
#   'date': '2023-05-07',
#   'time': '17:01:31'},
#  {'type': 'bike',
#   'count': 1,
#   'area': '۱۷ شهریور',
#   'date': '2023-05-07',
#   'time': '17:01:31'},
#  {'type': 'van',
#   'count': 128,
#   'area': '۱۷ شهریور',
#   'date': '2023-05-07',
#   'time': '17:01:31'},
#  {'type': 'van-heavy',
#   'count': 31,
#   'area': '۱۷ شهریور',
#   'date': '2023-05-07',
#   'time': '17:01:31'},
#  {'type': 'bike-without-box',
#   'count': 163,
#   'area': 'عباس آباد',
#   'date': '2023-05-07',
#   'time': '17:01:31'},
#  {'type': 'bike',
#   'count': 19,
#   'area': 'عباس آباد',
#   'date': '2023-05-07',
#   'time': '17:01:31'},
#  {'type': 'van',
#   'count': 51,
#   'area': 'عباس آباد',
#   'date': '2023-05-07',
#   'time': '17:01:31'},
#  {'type': 'van-heavy',
#   'count': 17,
#   'area': 'عباس آباد',
#   'date': '2023-05-07',
#   'time': '17:01:31'},
#  {'type': 'bike-without-box',
#   'count': 14,
#   'area': 'تهرانسر',
#   'date': '2023-05-07',
#   'time': '17:01:31'},
#  {'type': 'bike',
#   'count': 1,
#   'area': 'تهرانسر',
#   'date': '2023-05-07',
#   'time': '17:01:31'},
#  {'type': 'van',
#   'count': 19,
#   'area': 'تهرانسر',
#   'date': '2023-05-07',
#   'time': '17:01:31'},
#  {'type': 'van-heavy',
#   'count': 6,
#   'area': 'تهرانسر',
#   'date': '2023-05-07',
#   'time': '17:01:31'},
#  {'type': 'bike-without-box',
#   'count': 66,
#   'area': 'صادقیه',
#   'date': '2023-05-07',
#   'time': '17:01:31'},
#  {'type': 'bike',
#   'count': 8,
#   'area': 'صادقیه',
#   'date': '2023-05-07',
#   'time': '17:01:31'},
#  {'type': 'van',
#   'count': 55,
#   'area': 'صادقیه',
#   'date': '2023-05-07',
#   'time': '17:01:31'},
#  {'type': 'van-heavy',
#   'count': 12,
#   'area': 'صادقیه',
#   'date': '2023-05-07',
#   'time': '17:01:31'},
#  {'type': 'bike-without-box',
#   'count': 14,
#   'area': 'نازی آباد',
#   'date': '2023-05-07',
#   'time': '17:01:32'},
#  {'type': 'bike',
#   'count': 1,
#   'area': 'نازی آباد',
#   'date': '2023-05-07',
#   'time': '17:01:32'},
#  {'type': 'van',
#   'count': 170,
#   'area': 'نازی آباد',
#   'date': '2023-05-07',
#   'time': '17:01:32'},
#  {'type': 'van-heavy',
#   'count': 34,
#   'area': 'نازی آباد',
#   'date': '2023-05-07',
#   'time': '17:01:32'},
#  {'type': 'bike-without-box',
#   'count': 20,
#   'area': 'شهر ری',
#   'date': '2023-05-07',
#   'time': '17:01:32'},
#  {'type': 'bike',
#   'count': 3,
#   'area': 'شهر ری',
#   'date': '2023-05-07',
#   'time': '17:01:32'},
#  {'type': 'van',
#   'count': 75,
#   'area': 'شهر ری',
#   'date': '2023-05-07',
#   'time': '17:01:32'},
#  {'type': 'van-heavy',
#   'count': 20,
#   'area': 'شهر ری',
#   'date': '2023-05-07',
#   'time': '17:01:32'},
#  {'type': 'bike-without-box',
#   'count': 140,
#   'area': 'ونک',
#   'date': '2023-05-07',
#   'time': '17:01:32'},
#  {'type': 'bike',
#   'count': 14,
#   'area': 'ونک',
#   'date': '2023-05-07',
#   'time': '17:01:32'},
#  {'type': 'van',
#   'count': 56,
#   'area': 'ونک',
#   'date': '2023-05-07',
#   'time': '17:01:32'},
#  {'type': 'van-heavy',
#   'count': 20,
#   'area': 'ونک',
#   'date': '2023-05-07',
#   'time': '17:01:32'},
#  {'type': 'bike-without-box',
#   'count': 55,
#   'area': 'فردوس',
#   'date': '2023-05-07',
#   'time': '17:01:32'},
#  {'type': 'bike',
#   'count': 5,
#   'area': 'فردوس',
#   'date': '2023-05-07',
#   'time': '17:01:32'},
#  {'type': 'van',
#   'count': 44,
#   'area': 'فردوس',
#   'date': '2023-05-07',
#   'time': '17:01:32'},
#  {'type': 'van-heavy',
#   'count': 13,
#   'area': 'فردوس',
#   'date': '2023-05-07',
#   'time': '17:01:32'},
#  {'type': 'bike-without-box',
#   'count': 79,
#   'area': 'استادمعین',
#   'date': '2023-05-07',
#   'time': '17:01:32'},
#  {'type': 'bike',
#   'count': 12,
#   'area': 'استادمعین',
#   'date': '2023-05-07',
#   'time': '17:01:32'},
#  {'type': 'van',
#   'count': 76,
#   'area': 'استادمعین',
#   'date': '2023-05-07',
#   'time': '17:01:32'},
#  {'type': 'van-heavy',
#   'count': 26,
#   'area': 'استادمعین',
#   'date': '2023-05-07',
#   'time': '17:01:32'},
#  {'type': 'bike-without-box',
#   'count': 19,
#   'area': 'ارتش',
#   'date': '2023-05-07',
#   'time': '17:01:33'},
#  {'type': 'bike',
#   'count': 5,
#   'area': 'ارتش',
#   'date': '2023-05-07',
#   'time': '17:01:33'},
#  {'type': 'van',
#   'count': 15,
#   'area': 'ارتش',
#   'date': '2023-05-07',
#   'time': '17:01:33'},
#  {'type': 'van-heavy',
#   'count': 3,
#   'area': 'ارتش',
#   'date': '2023-05-07',
#   'time': '17:01:33'}]

# %%
# df2 = pd.DataFrame(data_list)

# %%
# df2

# %%
with pd.ExcelWriter("Near_Bikes_{}.xlsx".format(datetime.datetime.now().strftime("%X").replace(":", "_" ))) as writer:
    
    df2 = pd.DataFrame(data_list)
    
    df2.to_excel(writer, sheet_name='Near_Bikes', index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 with pd.ExcelWriter("Near_Bikes_{}.xlsx".format(datetime.datetime.now().strftime("%X"))) as writer:
#       3     df2 = pd.DataFrame(data_list)
#       5     df2.to_excel(writer, sheet_name='Near_Bikes', index=False)
#
# File ~\Work\pywinenv\Lib\site-packages\pandas\io\excel\_openpyxl.py:60, in OpenpyxlWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#      56 from openpyxl.workbook import Workbook
#      58 engine_kwargs = combine_kwargs(engine_kwargs, kwargs)
# ---> 60 super().__init__(
#      61     path,
#      62     mode=mode,
#      63     storage_options=storage_options,
#      64     if_sheet_exists=if_sheet_exists,
#      65     engine_kwargs=engine_kwargs,
#      66 )
#      68 # ExcelWriter replaced "a" by "r+" to allow us to first read the excel file from
#      69 # the file and later write to it
#      70 if "r+" in self._mode:  # Load from existing workbook
#
# File ~\Work\pywinenv\Lib\site-packages\pandas\io\excel\_base.py:1219, in ExcelWriter.__init__(self, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs)
#    1215 self._handles = IOHandles(
#    1216     cast(IO[bytes], path), compression={"compression": None}
#    1217 )
#    1218 if not isinstance(path, ExcelWriter):
# -> 1219     self._handles = get_handle(
#    1220         path, mode, storage_options=storage_options, is_text=False
#    1221     )
#    1222 self._cur_sheet = None
#    1224 if date_format is None:
#
# File ~\Work\pywinenv\Lib\site-packages\pandas\io\common.py:868, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#    (...)
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
# --> 868         handle = open(handle, ioargs.mode)
#     869     handles.append(handle)
#     871 # Convert BytesIO or file objects passed with an encoding
#
# OSError: [Errno 22] Invalid argument: 'Near_Bikes_17:01:33.xlsx'
